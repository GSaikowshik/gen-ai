# %% [markdown]
# <a href="https://colab.research.google.com/github/GSaikowshik/gen-ai/blob/main/session1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
file=pd.read_csv("/content/simplelinearregression.csv")

# %%
file
# Out:
#    Age  Premium
# 0   18    10000
# 1   22    15000
# 2   23    18000
# 3   26    21000
# 4   28    24000
# 5   31    26500
# 6   33    27000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(file["Age"],file["Premium"])

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(file[["Age"]],file["Premium"])
# Out:
# LinearRegression()

# %%
model.predict([[24]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([18035.95890411])

# %%
file=pd.read_csv("/content/multiple_linear_regression_dataset.csv")

# %%
file
# Out:
#     age  experience  income
# 0    25           1   30450
# 1    30           3   35670
# 2    47           2   31580
# 3    32           5   40130
# 4    43          10   47830
# 5    51           7   41630
# 6    28           5   41340
# 7    33           4   37650
# 8    37           5   40250
# 9    39           8   45150
# 10   29           1   27840
# 11   47           9   46110
# 12   54           5   36720
# 13   51           4   34800
# 14   44          12   51300
# 15   41           6   38900
# 16   58          17   63600
# 17   23           1   30870
# 18   44           9   44190
# 19   37          10   48700

# %%
plt.scatter(file["age"],file["income"])

# %%
model.fit(file[["age"]],file["experience"],file["income"])
# Out:
# LinearRegression()

# %%
model.predict([[44]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([7.94595393])
